# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import json
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the dataset
file_path = "GlobalElectricityStatistics.csv"
electricity_data = pd.read_csv(file_path)

# Display the first and last five rows of the DataFrame
print("First five rows:")
print(electricity_data.head())

print("\nLast five rows:")
print(electricity_data.tail())

# Show basic information about the DataFrame
print("\nBasic dataset information:")
print(f"Dataset dimensions: {electricity_data.shape}")
print("\nColumn details:")
print(electricity_data.info())

print("\nData types and memory usage:")
print(electricity_data.info(memory_usage='deep'))

print("\nStatistical summary of the data:")
print(electricity_data.describe())

# Check for missing values
print("\nMissing values check:")
missing_values = electricity_data.isnull().sum()
print(f"Number of missing values per column:\n{missing_values}")
print(f"Total number of missing values: {electricity_data.isnull().sum().sum()}")
print(f"Percentage of missing values: {(electricity_data.isnull().sum().sum() / (electricity_data.shape[0] * electricity_data.shape[1])) * 100:.2f}%")

# Handle missing values
# 1. Fill numeric missing data with 0 (assuming missing means no data or zero)
electricity_data_cleaned = electricity_data.fillna(0)

# 2. Check if any missing values remain
print("\nMissing values check after handling:")
print(f"Total remaining missing values: {electricity_data_cleaned.isnull().sum().sum()}")

# 3. Check for inconsistencies in the data - e.g., non-numeric values in numeric columns
# Assume all columns from the fourth onward represent yearly data
numeric_columns = electricity_data.columns[3:]
non_numeric_data = electricity_data[numeric_columns].applymap(lambda x: not pd.api.types.is_numeric_dtype(type(x)) and not pd.isna(x))
non_numeric_count = non_numeric_data.sum().sum()

print("\nNon-numeric data detection:")
print(f"Number of non-numeric entries in numeric columns: {non_numeric_count}")

if non_numeric_count > 0:
    # Show sample locations of non-numeric values
    print("Sample positions of non-numeric data:")
    for col in numeric_columns:
        non_numeric_in_col = electricity_data[non_numeric_data[col]][col]
        if len(non_numeric_in_col) > 0:
            print(f"Non-numeric values in column '{col}': {non_numeric_in_col.iloc[0:5].tolist() if len(non_numeric_in_col) > 5 else non_numeric_in_col.tolist()}")

    # Convert non-numeric values to NaN and fill them with 0
    for col in numeric_columns:
        electricity_data_cleaned[col] = pd.to_numeric(electricity_data[col], errors='coerce').fillna(0)

print("\nFirst five rows of cleaned data:")
print(electricity_data_cleaned.head())

# Save the cleaned data
electricity_data_cleaned.to_csv("GlobalElectricityStatistics_cleaned.csv", index=False)
print("\nCleaned data has been saved as 'GlobalElectricityStatistics_cleaned.csv'")
# Out:
# First five rows:
#           Country              Features          Region     1980     1981  \
# 0     Afghanistan  distribution losses   Asia & Oceania  0.06594  0.06944
# 1         Albania  distribution losses           Europe  0.16100  0.16100
# 2         Algeria  distribution losses           Africa  0.77700  0.95400
# 3  American Samoa  distribution losses   Asia & Oceania  0.00490  0.00469
# 4          Angola  distribution losses           Africa  0.16900  0.16900
#
#       1982     1983     1984     1985     1986  ...     2012      2013  \
# 0  0.06664  0.07000  0.07133  0.07238  0.07945  ...   0.4040   0.49000
# 1  0.16100  0.16000  0.16000  0.16100  0.16200  ...   1.1193   1.95349
# 2  1.06500  1.39000  1.64900  1.84600  1.85400  ...  11.0680  11.02300
# 3  0.00469  0.00497  0.00483  0.00581  0.00525  ...   0.0000   0.00000
# 4  0.18000  0.19600  0.16800  0.20200  0.20200  ...   0.6990   0.92600
#
#        2014    2015     2016       2017      2018      2019      2020  \
# 0   0.52000   0.522   0.5900   0.615000  0.640000  0.670000  0.670000
# 1   1.11907   1.250   1.9859   1.276047  1.155700  1.081830  0.932630
# 2  11.00300  11.196  10.6820  10.869000  9.904000  9.897000  8.980010
# 3   0.00000   0.000   0.0000   0.000000  0.012000  0.012000  0.013550
# 4   1.06800   1.078   1.1670   1.207373  1.447861  1.741409  1.845236
#
#        2021
# 0  0.666854
# 1  0.999072
# 2  8.770749
# 3  0.014069
# 4  1.868901
#
# [5 rows x 45 columns]
#
# Last five rows:
#             Country        Features          Region   1980   1981    1982  \
# 915     Wake Island  net generation  Asia & Oceania  0.000  0.000   0.000
# 916  Western Sahara  net generation          Africa  0.072  0.072   0.073
# 917           Yemen  net generation     Middle East  0.471  0.540   0.647
# 918          Zambia  net generation          Africa  9.172  9.809  10.024
# 919        Zimbabwe  net generation          Africa  4.465  4.476   4.097
#
#        1983   1984   1985   1986  ...      2012       2013       2014  \
# 915   0.000  0.000  0.000  0.000  ...   0.00000   0.000000   0.000000
# 916   0.073  0.073  0.071  0.074  ...   0.00000   0.000000   0.000000
# 917   0.721  0.818  0.855  1.094  ...   6.65162   7.995940   7.197240
# 918  10.051  9.912  9.958  9.811  ...  12.31092  13.231964  14.358504
# 919   4.387  4.502  4.992  5.955  ...   8.92948   9.255700   9.707120
#
#           2015       2016       2017       2018       2019       2020  \
# 915   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 916   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 917   5.923320   4.519420   3.818640   3.305880   3.414920   3.237250
# 918  13.359864  11.620963  14.434903  16.131655  14.660972  15.105044
# 919   9.387780   6.824940   7.349460   9.187000   8.230839   7.594010
#
#           2021
# 915   0.000000
# 916   0.000000
# 917   3.520874
# 918  17.714251
# 919   8.030894
#
# [5 rows x 45 columns]
#
# Basic dataset information:
# Dataset dimensions: (920, 45)
#
# Column details:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   920 non-null    object
#  1   Features  920 non-null    object
#  2   Region    920 non-null    object
#  3   1980      776 non-null    float64
#  4   1981      776 non-null    float64
#  5   1982      776 non-null    float64
#  6   1983      776 non-null    float64
#  7   1984      776 non-null    float64
#  8   1985      776 non-null    float64
#  9   1986      780 non-null    float64
#  10  1987      776 non-null    float64
#  11  1988      776 non-null    float64
#  12  1989      776 non-null    float64
#  13  1990      780 non-null    float64
#  14  1991      776 non-null    float64
#  15  1992      848 non-null    float64
#  16  1993      852 non-null    float64
#  17  1994      856 non-null    float64
#  18  1995      856 non-null    float64
#  19  1996      856 non-null    float64
#  20  1997      860 non-null    float64
#  21  1998      860 non-null    float64
#  22  1999      860 non-null    float64
#  23  2000      860 non-null    float64
#  24  2001      860 non-null    float64
#  25  2002      860 non-null    float64
#  26  2003      864 non-null    float64
#  27  2004      864 non-null    float64
#  28  2005      864 non-null    float64
#  29  2006      868 non-null    float64
#  30  2007      868 non-null    float64
#  31  2008      872 non-null    float64
#  32  2009      872 non-null    float64
#  33  2010      872 non-null    float64
#  34  2011      872 non-null    float64
#  35  2012      868 non-null    float64
#  36  2013      868 non-null    float64
#  37  2014      868 non-null    float64
#  38  2015      868 non-null    float64
#  39  2016      868 non-null    float64
#  40  2017      868 non-null    float64
#  41  2018      868 non-null    float64
#  42  2019      868 non-null    float64
#  43  2020      861 non-null    float64
#  44  2021      860 non-null    float64
# dtypes: float64(42), object(3)
# memory usage: 323.6+ KB
# None
#
# Data types and memory usage:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   920 non-null    object
#  1   Features  920 non-null    object
#  2   Region    920 non-null    object
#  3   1980      776 non-null    float64
#  4   1981      776 non-null    float64
#  5   1982      776 non-null    float64
#  6   1983      776 non-null    float64
#  7   1984      776 non-null    float64
#  8   1985      776 non-null    float64
#  9   1986      780 non-null    float64
#  10  1987      776 non-null    float64
#  11  1988      776 non-null    float64
#  12  1989      776 non-null    float64
#  13  1990      780 non-null    float64
#  14  1991      776 non-null    float64
#  15  1992      848 non-null    float64
#  16  1993      852 non-null    float64
#  17  1994      856 non-null    float64
#  18  1995      856 non-null    float64
#  19  1996      856 non-null    float64
#  20  1997      860 non-null    float64
#  21  1998      860 non-null    float64
#  22  1999      860 non-null    float64
#  23  2000      860 non-null    float64
#  24  2001      860 non-null    float64
#  25  2002      860 non-null    float64
#  26  2003      864 non-null    float64
#  27  2004      864 non-null    float64
#  28  2005      864 non-null    float64
#  29  2006      868 non-null    float64
#  30  2007      868 non-null    float64
#  31  2008      872 non-null    float64
#  32  2009      872 non-null    float64
#  33  2010      872 non-null    float64
#  34  2011      872 non-null    float64
#  35  2012      868 non-null    float64
#  36  2013      868 non-null    float64
#  37  2014      868 non-null    float64
#  38  2015      868 non-null    float64
#  39  2016      868 non-null    float64
#  40  2017      868 non-null    float64
#  41  2018      868 non-null    float64
#  42  2019      868 non-null    float64
#  43  2020      861 non-null    float64
#  44  2021      860 non-null    float64
# dtypes: float64(42), object(3)
# memory usage: 464.2 KB
# None
#
# Statistical summary of the data:
#               1980         1981         1982         1983         1984  \
# count   776.000000   776.000000   776.000000   776.000000   776.000000
# mean     11.601653    11.687294    11.946735    12.506693    13.160585
# std     100.562027   100.193093   100.729160   104.161406   109.275941
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.021385     0.024000     0.025000     0.026670     0.030000
# 75%       1.031250     1.094250     1.203250     1.397000     1.324000
# max    2289.600364  2297.973338  2244.372487  2313.445686  2419.465367
#
#               1985         1986         1987         1988         1989  ...  \
# count   776.000000   780.000000   776.000000   776.000000   776.000000  ...
# mean     13.779250    13.928575    14.715959    15.317672    16.175801  ...
# std     112.429291   112.403885   117.135128   122.256330   131.001065  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.031815     0.034500     0.037500     0.040195     0.047870  ...
# 75%       1.528500     1.564500     1.681500     1.677750     1.796250  ...
# max    2473.002120  2490.470952  2575.287667  2707.411178  2967.177014  ...
#
#               2012         2013         2014         2015         2016  \
# count   868.000000   868.000000   868.000000   868.000000   868.000000
# mean     28.729286    29.577280    30.126131    30.756771    31.540358
# std     226.475300   237.932684   244.880457   249.825415   258.913892
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.468350     0.474000     0.583777     0.581156     0.576002
# 75%       5.942690     6.662250     6.518750     6.262500     6.240263
# max    4740.272580  5171.548020  5400.113560  5584.765637  5904.640151
#
#               2017         2018         2019         2020         2021
# count   868.000000   868.000000   868.000000   861.000000   860.000000
# mean     32.410036    33.373588    33.816890    34.038380    35.820933
# std     271.811185   286.318951   295.385822   302.729583   325.977606
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.628000     0.602000     0.671000     0.672000     0.711950
# 75%       6.439000     6.286385     6.375674     6.671000     6.814849
# max    6389.805784  6800.815757  7152.505896  7455.467185  8151.518231
#
# [8 rows x 42 columns]
#
# Missing values check:
# Number of missing values per column:
# Country       0
# Features      0
# Region        0
# 1980        144
# 1981        144
# 1982        144
# 1983        144
# 1984        144
# 1985        144
# 1986        140
# 1987        144
# 1988        144
# 1989        144
# 1990        140
# 1991        144
# 1992         72
# 1993         68
# 1994         64
# 1995         64
# 1996         64
# 1997         60
# 1998         60
# 1999         60
# 2000         60
# 2001         60
# 2002         60
# 2003         56
# 2004         56
# 2005         56
# 2006         52
# 2007         52
# 2008         48
# 2009         48
# 2010         48
# 2011         48
# 2012         52
# 2013         52
# 2014         52
# 2015         52
# 2016         52
# 2017         52
# 2018         52
# 2019         52
# 2020         59
# 2021         60
# dtype: int64
# Total number of missing values: 3411
# Percentage of missing values: 8.24%
#
# Missing values check after handling:
# Total remaining missing values: 0
#
# Non-numeric data detection:
# Number of non-numeric entries in numeric columns: 0
#
# First five rows of cleaned data:
#           Country              Features          Region     1980     1981  \
# 0     Afghanistan  distribution losses   Asia & Oceania  0.06594  0.06944
# 1         Albania  distribution losses           Europe  0.16100  0.16100
# 2         Algeria  distribution losses           Africa  0.77700  0.95400
# 3  American Samoa  distribution losses   Asia & Oceania  0.00490  0.00469
# 4          Angola  distribution losses           Africa  0.16900  0.16900
#
#       1982     1983     1984     1985     1986  ...     2012      2013  \
# 0  0.06664  0.07000  0.07133  0.07238  0.07945  ...   0.4040   0.49000
# 1  0.16100  0.16000  0.16000  0.16100  0.16200  ...   1.1193   1.95349
# 2  1.06500  1.39000  1.64900  1.84600  1.85400  ...  11.0680  11.02300
# 3  0.00469  0.00497  0.00483  0.00581  0.00525  ...   0.0000   0.00000
# 4  0.18000  0.19600  0.16800  0.20200  0.20200  ...   0.6990   0.92600
#
#        2014    2015     2016       2017      2018      2019      2020  \
# 0   0.52000   0.522   0.5900   0.615000  0.640000  0.670000  0.670000
# 1   1.11907   1.250   1.9859   1.276047  1.155700  1.081830  0.932630
# 2  11.00300  11.196  10.6820  10.869000  9.904000  9.897000  8.980010
# 3   0.00000   0.000   0.0000   0.000000  0.012000  0.012000  0.013550
# 4   1.06800   1.078   1.1670   1.207373  1.447861  1.741409  1.845236
#
#        2021
# 0  0.666854
# 1  0.999072
# 2  8.770749
# 3  0.014069
# 4  1.868901
#
# [5 rows x 45 columns]
#
# Cleaned data has been saved as 'GlobalElectricityStatistics_cleaned.csv'

# %%
selected_countries = ['China', 'Vietnam', 'United States', 'Japan', 'United Kingdom']
electricity_viz_data = electricity_data_cleaned[electricity_data_cleaned['Country'].isin(selected_countries)]


year_columns_to_check = [col for col in electricity_viz_data.columns if col.isdigit() or (isinstance(col, str) and col.isnumeric())]


years_to_plot_str = [str(year) for year in range(1980, 2022)]
years_present = [col for col in years_to_plot_str if col in electricity_viz_data.columns]


aggregated_data = electricity_viz_data.groupby('Country')[years_present].sum()


plot_data = aggregated_data.T
plot_data.index = plot_data.index.astype(int)  # Convert year index to int for correct sorting


plt.figure(figsize=(15, 8))

for country in selected_countries:
    if country in plot_data.columns:
        plt.plot(plot_data.index, plot_data[country], label=country, marker='o', linestyle='-')

# Add title and labels
plt.title('Net Electricity Generation Trend (1980-2021) for Selected Countries', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Net Electricity Generation (GWh or relevant unit)', fontsize=14)
plt.legend(title='Country', fontsize=10, title_fontsize='12')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45, ha='right')
plt.xlim(1980, 2021) 
plt.tight_layout()
plt.show()

# %%
# 1.3 Data Aggregation and Summary

years_for_avg_str = [str(year) for year in range(2000, 2022)]

years_present_for_avg = [
    col for col in years_for_avg_str 
    if col in electricity_data_cleaned.columns and pd.api.types.is_numeric_dtype(electricity_data_cleaned[col])
]

if not years_present_for_avg:
    print("Error: No numeric year data found for 2000–2021 in the dataset.")
else:
    avg_electricity_data = electricity_data_cleaned[['Country'] + years_present_for_avg].copy()  # Use .copy() to avoid SettingWithCopyWarning

    # Clean step
    if avg_electricity_data['Country'].duplicated().any():
        print("Duplicate country entries detected. Aggregating data by country...")
        # Sum numeric columns per country
        numeric_cols_to_sum = [col for col in years_present_for_avg if pd.api.types.is_numeric_dtype(avg_electricity_data[col])]
        if not numeric_cols_to_sum:
            print("Warning: No numeric year columns found for aggregation.")
        avg_electricity_data = avg_electricity_data.groupby('Country', as_index=False)[numeric_cols_to_sum].sum()

    # Compute
    avg_electricity_data['Average Generation (2000-2021)'] = avg_electricity_data[years_present_for_avg].mean(axis=1)

    # Display average
    print("\nAverage Annual Electricity Generation (2000–2021) by Country:")
    avg_generation_sorted = avg_electricity_data[['Country', 'Average Generation (2000-2021)']].sort_values(
        by='Average Generation (2000-2021)', ascending=False)
    print(avg_generation_sorted)

    # b. Identify and display the countries with the highest and lowest average generation
    highest_avg_country = avg_electricity_data.loc[avg_electricity_data['Average Generation (2000-2021)'].idxmax()]

    # Filter non-zero data
    non_zero_avg_data = avg_electricity_data[avg_electricity_data['Average Generation (2000-2021)'] > 0]
    if not non_zero_avg_data.empty:
        lowest_avg_country = non_zero_avg_data.loc[non_zero_avg_data['Average Generation (2000-2021)'].idxmin()]
    else:
        lowest_avg_country = pd.Series({
            'Country': "N/A (All countries have zero or missing average generation)",
            'Average Generation (2000-2021)': 0.0
        })

    print("\nCountry with the Highest Average Generation (2000–2021):")
    print(highest_avg_country[['Country', 'Average Generation (2000-2021)']])
    print("\nCountry with the Lowest Non-Zero Average Generation (2000–2021):")
    print(lowest_avg_country[['Country', 'Average Generation (2000-2021)']])

    # c. Visualize the average generation comparison for selected countries
    avg_selected_countries_data = avg_electricity_data[avg_electricity_data['Country'].isin(selected_countries)]

    plt.figure(figsize=(12, 7))
    sns.barplot(x='Country', y='Average Generation (2000-2021)', data=avg_selected_countries_data,
                palette='viridis', hue='Country', legend=False)
    plt.title('Average Electricity Generation (2000–2021) for Selected Countries', fontsize=16)
    plt.xlabel('Country', fontsize=14)
    plt.ylabel('Average Net Electricity Generation (GWh or relevant unit)', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Duplicate country entries detected. Aggregating data by country...
#
# Average Annual Electricity Generation (2000–2021) by Country:
#                    Country  Average Generation (2000-2021)
# 40                   China                     4553.179078
# 219          United States                     4357.464005
# 98                   India                     1262.613957
# 169                 Russia                     1101.134016
# 106                  Japan                     1052.471425
# ..                     ...                             ...
# 71       Former Yugoslavia                        0.000000
# 70         Former U.S.S.R.                        0.000000
# 133             Micronesia                        0.000000
# 68   Former Czechoslovakia                        0.000000
# 93     Hawaiian Trade Zone                        0.000000
#
# [230 rows x 2 columns]
#
# Country with the Highest Average Generation (2000–2021):
# Country                                 China
# Average Generation (2000-2021)    4553.179078
# Name: 40, dtype: object
#
# Country with the Lowest Non-Zero Average Generation (2000–2021):
# Country                           Antarctica
# Average Generation (2000-2021)      0.001143
# Name: 5, dtype: object

# %%
# Task 2: Prediction Modeling and Discussion

# 2.1 Data Preparation for Prediction

# Read
original_data = pd.read_csv("GlobalElectricityStatistics.csv")
print("Columns in the original dataset:", original_data.columns[:10].tolist(), "...")

# Check unique
print("Unique values in the 'Features' column of the original dataset:")
print(original_data['Features'].unique())

# Filter
net_generation_data = original_data[original_data['Features'].str.strip().str.lower() == 'net generation'].copy()
imports_data = original_data[original_data['Features'].str.strip().str.lower() == 'imports'].copy()
exports_data = original_data[original_data['Features'].str.strip().str.lower() == 'exports'].copy()
distribution_losses_data = original_data[original_data['Features'].str.strip().str.lower() == 'distribution losses'].copy()

print(f"Number of net generation records: {len(net_generation_data)}")
print(f"Number of import records: {len(imports_data)}")
print(f"Number of export records: {len(exports_data)}")
print(f"Number of distribution loss records: {len(distribution_losses_data)}")

# a. Calculate net consumption values for each country from 1980 to 2021

year_columns = [str(year) for year in range(1980, 2022)]

all_countries = pd.unique(original_data['Country'])
print(f"\nTotal number of countries/regions: {len(all_countries)}")

net_consumption_df = pd.DataFrame(index=all_countries)

def get_value_for_country_year(df, country, year):
    try:
        value = df[df['Country'] == country][year].values
        return float(value[0]) if len(value) > 0 else 0
    except Exception:
        return 0

for year in year_columns:
    year_consumption = []
    
    for country in all_countries:
        net_gen = get_value_for_country_year(net_generation_data, country, year)
        imports = get_value_for_country_year(imports_data, country, year)
        exports = get_value_for_country_year(exports_data, country, year)
        losses = get_value_for_country_year(distribution_losses_data, country, year)
        
        # Compute
        net_consumption = net_gen + imports - exports - losses
        year_consumption.append(net_consumption)
    
    net_consumption_df[year] = year_consumption

net_consumption_df.reset_index(inplace=True)
net_consumption_df.rename(columns={'index': 'Country'}, inplace=True)

# Display 
print("\nFirst few rows of annual net consumption data by country:")
print(net_consumption_df[['Country'] + year_columns[:5]].head())

# b. Select the country with the highest average net consumption

# Compute
net_consumption_df['Average Net Consumption'] = net_consumption_df[year_columns].mean(axis=1)

# Sort 
top_countries = net_consumption_df.sort_values('Average Net Consumption', ascending=False).head(10)
print("\nTop 10 countries by average net electricity consumption:")
print(top_countries[['Country', 'Average Net Consumption']])

# Get
top_country = top_countries.iloc[0]['Country']
top_country_avg = top_countries.iloc[0]['Average Net Consumption']
print(f"\nThe country with the highest average net consumption is: {top_country}")
print(f"Average net consumption: {top_country_avg:.2f} GWh")

# Plot
plt.figure(figsize=(15, 7))
top_country_data = net_consumption_df[net_consumption_df['Country'] == top_country]
years = [int(year) for year in year_columns]
values = [top_country_data[year].values[0] for year in year_columns]

plt.plot(years, values, marker='o', linewidth=2)
plt.title(f'{top_country} Net Electricity Consumption (1980–2021)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Net Electricity Consumption (GWh)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(years[::5], rotation=45)  # Show every 5 years
plt.tight_layout()
plt.show()

# c. Split net consumption data into training and testing sets for the selected country
from sklearn.model_selection import train_test_split

# Prepare time series data
time_series_data = pd.DataFrame({
    'Year': years,
    'Net Consumption': values
})

actual_consumption = pd.DataFrame({
    'Year': [2022, 2023, 2024],
    'Actual Net Consumption (GWh)': [4128.2, 4084.6, 4086.0]  # Actual data from energy databases https://countryeconomy.com/energy-and-environment/electricity-consumption
})

print("\nHead of time series data:")
print(time_series_data.head())
print(time_series_data.tail())
# Out:
# Columns in the original dataset: ['Country', 'Features', 'Region', '1980', '1981', '1982', '1983', '1984', '1985', '1986'] ...
# Unique values in the 'Features' column of the original dataset:
# ['distribution losses ' 'exports ' 'imports ' 'net generation']
# Number of net generation records: 230
# Number of import records: 230
# Number of export records: 230
# Number of distribution loss records: 230
#
# Total number of countries/regions: 230
#
# First few rows of annual net consumption data by country:
#           Country     1980     1981     1982     1983     1984
# 0     Afghanistan  0.87606  0.92256  0.88536  0.93000  0.94767
# 1         Albania  2.97400  2.98700  2.98100  2.97500  2.97700
# 2         Algeria  5.91500  6.71300  7.73300  8.20700  8.95900
# 3  American Samoa  0.06510  0.06231  0.06231  0.06603  0.06417
# 4          Angola  0.73600  0.73700  0.81500  0.83200  0.86000
#
# Top 10 countries by average net electricity consumption:
#              Country  Average Net Consumption
# 219    United States              3306.676570
# 40             China              2398.511026
# 70   Former U.S.S.R.              1339.461178
# 106            Japan               853.626752
# 169           Russia               818.804545
# 98             India               543.380606
# 78           Germany               521.355738
# 35            Canada               481.029848
# 72            France               385.871328
# 80     Germany, West               384.013818
#
# The country with the highest average net consumption is: United States
# Average net consumption: 3306.68 GWh
#
# First few rows of annual net consumption data by country:
#           Country     1980     1981     1982     1983     1984
# 0     Afghanistan  0.87606  0.92256  0.88536  0.93000  0.94767
# 1         Albania  2.97400  2.98700  2.98100  2.97500  2.97700
# 2         Algeria  5.91500  6.71300  7.73300  8.20700  8.95900
# 3  American Samoa  0.06510  0.06231  0.06231  0.06603  0.06417
# 4          Angola  0.73600  0.73700  0.81500  0.83200  0.86000
#
# Top 10 countries by average net electricity consumption:
#              Country  Average Net Consumption
# 219    United States              3306.676570
# 40             China              2398.511026
# 70   Former U.S.S.R.              1339.461178
# 106            Japan               853.626752
# 169           Russia               818.804545
# 98             India               543.380606
# 78           Germany               521.355738
# 35            Canada               481.029848
# 72            France               385.871328
# 80     Germany, West               384.013818
#
# The country with the highest average net consumption is: United States
# Average net consumption: 3306.68 GWh
# Head of time series data:
#    Year  Net Consumption
# 0  1980      2094.449000
# 1  1981      2147.102862
# 2  1982      2086.441352
# 3  1983      2150.954584
# 4  1984      2285.796394
#     Year  Net Consumption
# 37  2017      3888.305646
# 38  2018      4032.628268
# 39  2019      3989.378249
# 40  2020      3897.894198
# 41  2021      3979.279761

# %%
# Data preparation: split into train, validation, and test sets
print("Prepare For Hyperparameter Optimization - Improving MLP Model Performance")

# Ensure data is sorted
ordered_data = time_series_data.sort_values(by="Year")
X_ordered = ordered_data[["Year"]].values
y_ordered = ordered_data["Net Consumption"].values

# Normalize data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler() 
X_scaled = scaler_X.fit_transform(X_ordered.reshape(-1, 1))
y_scaled = scaler_y.fit_transform(y_ordered.reshape(-1, 1))

# Split into train (70%), val (15%), test (15%)
train_size = int(len(X_scaled) * 0.7)
val_size = int(len(X_scaled) * 0.15)
test_size = len(X_scaled) - train_size - val_size

X_train_hpo = X_scaled[:train_size]
X_val_hpo = X_scaled[train_size : train_size + val_size]
X_test_hpo = X_scaled[train_size + val_size :]

y_train_hpo = y_scaled[:train_size]
y_val_hpo = y_scaled[train_size : train_size + val_size]
y_test_hpo = y_scaled[train_size + val_size :]

# Convert to PyTorch tensors
device = torch.device("cpu")
X_train_tensor_hpo = torch.FloatTensor(X_train_hpo).to(device)
y_train_tensor_hpo = torch.FloatTensor(y_train_hpo).to(device)
X_val_tensor_hpo = torch.FloatTensor(X_val_hpo).to(device)
y_val_tensor_hpo = torch.FloatTensor(y_val_hpo).to(device)
X_test_tensor_hpo = torch.FloatTensor(X_test_hpo).to(device)
y_test_tensor_hpo = torch.FloatTensor(y_test_hpo).to(device)

print(f"Train set size: {X_train_tensor_hpo.shape}, {y_train_tensor_hpo.shape}")
print(f"Validation set size: {X_val_tensor_hpo.shape}, {y_val_tensor_hpo.shape}")
print(f"Test set size: {X_test_tensor_hpo.shape}, {y_test_tensor_hpo.shape}")

# Activation function mapping
activation_functions_map = {
    "ReLU": nn.ReLU,
    "LeakyReLU": lambda: nn.LeakyReLU(0.1),
    "ELU": nn.ELU,
    "GELU": nn.GELU,
}

# Plotting the data splits
plt.figure(figsize=(15, 7))

# Original data (unscaled, for x-axis use original years)
# X_ordered contains the original years, y_ordered contains the original net consumption
original_years = X_ordered.flatten() # Flatten if it's a column vector

# Plot training data
plt.plot(original_years[:train_size], y_ordered[:train_size], 'bo-', label='Training Data', markersize=5)

# Plot validation data
plt.plot(original_years[train_size : train_size + val_size], y_ordered[train_size : train_size + val_size], 'go-', label='Validation Data', markersize=5)

# Plot testing data
plt.plot(original_years[train_size + val_size :], y_ordered[train_size + val_size :], 'ro-', label='Testing Data', markersize=5)

plt.title(f'{top_country} - Data Splits for Hyperparameter Optimization', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Net Consumption (Original Scale)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Prepare For Hyperparameter Optimization - Improving MLP Model Performance
# Train set size: torch.Size([29, 1]), torch.Size([29, 1])
# Validation set size: torch.Size([6, 1]), torch.Size([6, 1])
# Test set size: torch.Size([7, 1]), torch.Size([7, 1])

# %%
RUN_OPTUNA_OPTIMIZATION = False

# %%
# Flexible MLP Model definition with variable layers and neuron counts
class FlexibleMLPModel(nn.Module):
    def __init__(
        self,
        input_dim=1,
        hidden_layers=None,
        output_dim=1,
        dropout_rate=0.2,
        activation_func=nn.ReLU,
    ):
        super(FlexibleMLPModel, self).__init__()

        if hidden_layers is None:
            hidden_layers = [64, 32]

        # First layer - input to first hidden layer
        layers = [nn.Linear(input_dim, hidden_layers[0])]

        # Hidden layers
        for i in range(len(hidden_layers) - 1):
            layers.append(activation_func())
            layers.append(nn.Dropout(dropout_rate))
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i + 1]))

        # Output layer
        layers.append(activation_func())
        layers.append(nn.Dropout(dropout_rate))
        layers.append(nn.Linear(hidden_layers[-1], output_dim))

        self.model = nn.Sequential(*layers)

        # Initialize weights
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        if len(x.shape) == 1:
            x = x.unsqueeze(1)  # Add feature dimension

        return self.model(x)


# Model evaluation function: calculate MSE and R²
def evaluate_model(model, X_test, y_test, scaler_y=None):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test)
        
        if scaler_y:
            # If scaler is provided, inverse transform for real-world metrics
            y_test_original = scaler_y.inverse_transform(y_test.cpu().numpy())
            y_pred_original = scaler_y.inverse_transform(y_pred.cpu().numpy())
            mse = mean_squared_error(y_test_original, y_pred_original)
            r2 = r2_score(y_test_original, y_pred_original)
        else:
            r2 = r2_score(y_test.cpu().numpy(), y_pred.cpu().numpy())

    return mse, r2


# Train model with early stopping
def train_model_with_early_stopping(
    model,
    X_train,
    y_train,
    X_val,
    y_val,
    optimizer,
    criterion,
    patience=30,
    max_epochs=500,
    verbose=False,
):
    best_val_loss = float("inf")
    no_improve_epochs = 0
    best_model_state = None

    for epoch in range(max_epochs):
        # Training mode
        model.train()
        optimizer.zero_grad()
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()

        # Evaluation mode
        model.eval()
        with torch.no_grad():
            val_pred = model(X_val)
            val_loss = criterion(val_pred, y_val).item()

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            no_improve_epochs = 0
            best_model_state = model.state_dict().copy()
        else:
            no_improve_epochs += 1

        if no_improve_epochs >= patience:
            if verbose:
                print(f"Early stopping at epoch {epoch + 1}")
            model.load_state_dict(best_model_state)
            break

        if verbose and epoch % 50 == 0:
            print(
                f"Epoch {epoch + 1}/{max_epochs}, Train Loss: {loss.item():.6f}, Val Loss: {val_loss:.6f}"
            )

    if best_model_state:
        model.load_state_dict(best_model_state)

    return best_val_loss

print("✅ FlexibleMLPModel and helper functions defined and ready for use.")
# Out:
# ✅ FlexibleMLPModel and helper functions defined and ready for use.

# %%
# This cell loads best hyperparameters from best_params.json and rebuilds/trains the model in English.

final_best_model = None
final_best_params = None
final_best_scores = (float('nan'), float('nan')) # (mse, r2)
optuna_study = None

if RUN_OPTUNA_OPTIMIZATION:
    print("🚀 Running Optuna hyperparameter optimization...")
    n_trials_optuna = 50000
    final_best_model, final_best_params, final_best_scores, optuna_study = run_hyperparameter_optimization(
        X_train_tensor_hpo, y_train_tensor_hpo,
        X_val_tensor_hpo, y_val_tensor_hpo,
        X_test_tensor_hpo, y_test_tensor_hpo,
        scaler_y=scaler_y,
        device=device,
        n_trials=n_trials_optuna,
        study_name="mlp_electricity_forecasting_conditional"
    )
    print("✅ Optuna optimization completed.")

else:
    print("💡 Loading saved best hyperparameters and rebuilding/training model...")
    params_filepath = "best_params.json"
    try:
        with open(params_filepath, "r") as f:
            loaded_params = json.load(f)
        print(f"Successfully loaded hyperparameters from {params_filepath}.")
        print(f"📄 Loaded best_params.json content:")
        print(json.dumps(loaded_params, indent=4))
        final_best_params = loaded_params

        input_dim_hpo = X_train_tensor_hpo.shape[1]
        output_dim_hpo = y_train_tensor_hpo.shape[1] if len(y_train_tensor_hpo.shape) > 1 else 1

        n_layers = loaded_params["n_layers"]
        hidden_layers_conf = [loaded_params[f"n_units_l{i}"] for i in range(n_layers)]

        activation_name = loaded_params["activation"]
        activation_func_loaded = activation_functions_map[activation_name]

        reconstructed_model = FlexibleMLPModel(
            input_dim=input_dim_hpo,
            hidden_layers=hidden_layers_conf,
            output_dim=output_dim_hpo,
            dropout_rate=loaded_params["dropout_rate"],
            activation_func=activation_func_loaded,
        ).to(device)
        print("Model rebuilt according to loaded hyperparameters.")

        print("Training rebuilt model on combined train+val set with loaded best parameters...")

        optimizer_name_loaded = loaded_params["optimizer"]
        lr_loaded = loaded_params["learning_rate"]
        wd_loaded = loaded_params["weight_decay"]

        if optimizer_name_loaded == "Adam":
            optimizer_loaded = optim.Adam(reconstructed_model.parameters(), lr=lr_loaded, weight_decay=wd_loaded)
        elif optimizer_name_loaded == "RMSprop":
            optimizer_loaded = optim.RMSprop(reconstructed_model.parameters(), lr=lr_loaded, weight_decay=wd_loaded)
        else: # SGD
            optimizer_loaded = optim.SGD(reconstructed_model.parameters(), lr=lr_loaded, weight_decay=wd_loaded, momentum=0.9)

        criterion_loaded = nn.MSELoss()
        X_full_train_hpo = torch.cat([X_train_tensor_hpo, X_val_tensor_hpo], dim=0)
        y_full_train_hpo = torch.cat([y_train_tensor_hpo, y_val_tensor_hpo], dim=0)

        reconstructed_model.train()
        max_epochs_final_train = 50000

        for epoch in range(max_epochs_final_train):
            optimizer_loaded.zero_grad()
            y_pred_rt = reconstructed_model(X_full_train_hpo)
            loss_rt = criterion_loaded(y_pred_rt, y_full_train_hpo)
            loss_rt.backward()
            optimizer_loaded.step()
            if (epoch + 1) % 100 == 0:
                print(f"Training rebuilt model - Epoch {epoch + 1}/{max_epochs_final_train}, Loss: {loss_rt.item():.6f}")

        final_best_model = reconstructed_model
        print("✅ Rebuilt model training completed.")

        print("Evaluating loaded and trained model...")
        mse_loaded, r2_loaded = evaluate_model(final_best_model, X_test_tensor_hpo, y_test_tensor_hpo, scaler_y)
        final_best_scores = (mse_loaded, r2_loaded)
        print(f"Loaded/rebuilt model test set evaluation - MSE: {mse_loaded:.6f}, R²: {r2_loaded:.6f}")

    except FileNotFoundError:
        print(f"Error: Hyperparameter file {params_filepath} not found. Please run Optuna optimization first or check the file path.")
    except Exception as e:
        print(f"Error loading or rebuilding model: {e}")

if final_best_model:
    print("\nModel is ready for further evaluation and prediction.")
else:
    print("\nWarning: Model was not successfully loaded or trained. Subsequent cells may not work properly.")
# Out:
# 💡 Loading saved best hyperparameters and rebuilding/training model...
# Successfully loaded hyperparameters from best_params.json.
# 📄 Loaded best_params.json content:
# {
#     "n_layers": 4,
#     "n_units_l0": 162,
#     "n_units_l1": 187,
#     "n_units_l2": 115,
#     "n_units_l3": 55,
#     "dropout_rate": 0.24726403007037911,
#     "learning_rate": 0.00895484844273611,
#     "weight_decay": 5.493694747461835e-05,
#     "activation": "LeakyReLU",
#     "optimizer": "RMSprop",
#     "patience": 56
# }
# Model rebuilt according to loaded hyperparameters.
# Training rebuilt model on combined train+val set with loaded best parameters...
# Training rebuilt model - Epoch 100/50000, Loss: 0.218900
# Training rebuilt model - Epoch 200/50000, Loss: 0.109319
# Training rebuilt model - Epoch 300/50000, Loss: 0.058223
# Training rebuilt model - Epoch 400/50000, Loss: 0.043570
# Training rebuilt model - Epoch 500/50000, Loss: 0.045936
# Training rebuilt model - Epoch 600/50000, Loss: 0.042932
# Training rebuilt model - Epoch 700/50000, Loss: 0.027393
# Training rebuilt model - Epoch 800/50000, Loss: 0.032432
# Training rebuilt model - Epoch 900/50000, Loss: 0.019947
# Training rebuilt model - Epoch 1000/50000, Loss: 0.018070
# Training rebuilt model - Epoch 1100/50000, Loss: 0.017567
# Training rebuilt model - Epoch 1200/50000, Loss: 0.024420
# Training rebuilt model - Epoch 1300/50000, Loss: 0.005810
# Training rebuilt model - Epoch 1400/50000, Loss: 0.010056
# Training rebuilt model - Epoch 1500/50000, Loss: 0.007920
# Training rebuilt model - Epoch 1600/50000, Loss: 0.006009
# Training rebuilt model - Epoch 1700/50000, Loss: 0.009104
# Training rebuilt model - Epoch 1800/50000, Loss: 0.009122
# Training rebuilt model - Epoch 1900/50000, Loss: 0.005375
# Training rebuilt model - Epoch 2000/50000, Loss: 0.006414
# Training rebuilt model - Epoch 2100/50000, Loss: 0.006418
# Training rebuilt model - Epoch 2200/50000, Loss: 0.005274
# Training rebuilt model - Epoch 2300/50000, Loss: 0.005242
# Training rebuilt model - Epoch 2400/50000, Loss: 0.007411
# Training rebuilt model - Epoch 2500/50000, Loss: 0.443749
# Training rebuilt model - Epoch 2600/50000, Loss: 0.010011
# Training rebuilt model - Epoch 2700/50000, Loss: 0.003725
# Training rebuilt model - Epoch 2800/50000, Loss: 0.004470
# Training rebuilt model - Epoch 2900/50000, Loss: 0.008848
# Training rebuilt model - Epoch 3000/50000, Loss: 0.010459
# Training rebuilt model - Epoch 3100/50000, Loss: 0.009106
# Training rebuilt model - Epoch 3200/50000, Loss: 0.008767
# Training rebuilt model - Epoch 3300/50000, Loss: 0.009275
# Training rebuilt model - Epoch 3400/50000, Loss: 0.014474
# Training rebuilt model - Epoch 3500/50000, Loss: 0.005015
# Training rebuilt model - Epoch 3600/50000, Loss: 0.009791
# Training rebuilt model - Epoch 3700/50000, Loss: 0.005974
# Training rebuilt model - Epoch 3800/50000, Loss: 0.006956
# Training rebuilt model - Epoch 3900/50000, Loss: 0.006921
# Training rebuilt model - Epoch 4000/50000, Loss: 0.012230
# Training rebuilt model - Epoch 4100/50000, Loss: 0.007060
# Training rebuilt model - Epoch 4200/50000, Loss: 0.013484
# Training rebuilt model - Epoch 4300/50000, Loss: 0.006853
# Training rebuilt model - Epoch 4400/50000, Loss: 0.009267
# Training rebuilt model - Epoch 4500/50000, Loss: 0.005730
# Training rebuilt model - Epoch 4600/50000, Loss: 0.005043
# Training rebuilt model - Epoch 4700/50000, Loss: 0.007470
# Training rebuilt model - Epoch 4800/50000, Loss: 0.005557
# Training rebuilt model - Epoch 4900/50000, Loss: 0.006368
# Training rebuilt model - Epoch 5000/50000, Loss: 0.008577
# Training rebuilt model - Epoch 5100/50000, Loss: 0.016922
# Training rebuilt model - Epoch 5200/50000, Loss: 0.008503
# Training rebuilt model - Epoch 5300/50000, Loss: 0.007123
# Training rebuilt model - Epoch 5400/50000, Loss: 0.005419
# Training rebuilt model - Epoch 5500/50000, Loss: 0.010226
# Training rebuilt model - Epoch 5600/50000, Loss: 0.007832
# Training rebuilt model - Epoch 5700/50000, Loss: 0.010840
# Training rebuilt model - Epoch 5800/50000, Loss: 0.005155
# Training rebuilt model - Epoch 5900/50000, Loss: 0.004927
# Training rebuilt model - Epoch 6000/50000, Loss: 0.008087
# Training rebuilt model - Epoch 6100/50000, Loss: 0.007717
# Training rebuilt model - Epoch 6200/50000, Loss: 0.087315
# Training rebuilt model - Epoch 6300/50000, Loss: 0.041273
# Training rebuilt model - Epoch 6400/50000, Loss: 0.020811
# Training rebuilt model - Epoch 6500/50000, Loss: 0.015884
# Training rebuilt model - Epoch 6600/50000, Loss: 0.029880
# Training rebuilt model - Epoch 6700/50000, Loss: 0.007842
# Training rebuilt model - Epoch 6800/50000, Loss: 0.009757
# Training rebuilt model - Epoch 6900/50000, Loss: 0.012102
# Training rebuilt model - Epoch 7000/50000, Loss: 0.007234
# Training rebuilt model - Epoch 7100/50000, Loss: 0.013270
# Training rebuilt model - Epoch 7200/50000, Loss: 0.010966
# Training rebuilt model - Epoch 7300/50000, Loss: 0.007674
# Training rebuilt model - Epoch 7400/50000, Loss: 0.006074
# Training rebuilt model - Epoch 7500/50000, Loss: 0.010872
# Training rebuilt model - Epoch 7600/50000, Loss: 0.043335
# Training rebuilt model - Epoch 7700/50000, Loss: 0.015440
# Training rebuilt model - Epoch 7800/50000, Loss: 0.008283
# Training rebuilt model - Epoch 7900/50000, Loss: 0.009727
# Training rebuilt model - Epoch 8000/50000, Loss: 0.013587
# Training rebuilt model - Epoch 8100/50000, Loss: 0.013411
# Training rebuilt model - Epoch 8200/50000, Loss: 0.013428
# Training rebuilt model - Epoch 8300/50000, Loss: 0.011322
# Training rebuilt model - Epoch 8400/50000, Loss: 0.008900
# Training rebuilt model - Epoch 8500/50000, Loss: 0.005373
# Training rebuilt model - Epoch 8600/50000, Loss: 0.014370
# Training rebuilt model - Epoch 8700/50000, Loss: 0.025872
# Training rebuilt model - Epoch 8800/50000, Loss: 0.006101
# Training rebuilt model - Epoch 8900/50000, Loss: 0.004857
# Training rebuilt model - Epoch 9000/50000, Loss: 0.014731
# Training rebuilt model - Epoch 9100/50000, Loss: 0.006445
# Training rebuilt model - Epoch 9200/50000, Loss: 0.006297
# Training rebuilt model - Epoch 9300/50000, Loss: 0.006555
# Training rebuilt model - Epoch 9400/50000, Loss: 0.006583
# Training rebuilt model - Epoch 9500/50000, Loss: 0.012404
# Training rebuilt model - Epoch 9600/50000, Loss: 0.007328
# Training rebuilt model - Epoch 9700/50000, Loss: 0.012501
# Training rebuilt model - Epoch 9800/50000, Loss: 0.008539
# Training rebuilt model - Epoch 9900/50000, Loss: 0.003579
# Training rebuilt model - Epoch 10000/50000, Loss: 0.010743
# Training rebuilt model - Epoch 10100/50000, Loss: 0.007888
# Training rebuilt model - Epoch 10200/50000, Loss: 0.153146
# Training rebuilt model - Epoch 10300/50000, Loss: 0.043344
# Training rebuilt model - Epoch 10400/50000, Loss: 0.019988
# Training rebuilt model - Epoch 10500/50000, Loss: 0.017749
# Training rebuilt model - Epoch 10600/50000, Loss: 0.015367
# Training rebuilt model - Epoch 10700/50000, Loss: 0.008272
# Training rebuilt model - Epoch 10800/50000, Loss: 0.008196
# Training rebuilt model - Epoch 10900/50000, Loss: 0.009447
# Training rebuilt model - Epoch 11000/50000, Loss: 0.009413
# Training rebuilt model - Epoch 11100/50000, Loss: 0.028210
# Training rebuilt model - Epoch 11200/50000, Loss: 0.007470
# Training rebuilt model - Epoch 11300/50000, Loss: 0.014864
# Training rebuilt model - Epoch 11400/50000, Loss: 0.015709
# Training rebuilt model - Epoch 11500/50000, Loss: 0.008274
# Training rebuilt model - Epoch 11600/50000, Loss: 0.010873
# Training rebuilt model - Epoch 11700/50000, Loss: 0.005621
# Training rebuilt model - Epoch 11800/50000, Loss: 0.004339
# Training rebuilt model - Epoch 11900/50000, Loss: 0.005017
# Training rebuilt model - Epoch 12000/50000, Loss: 0.012562
# Training rebuilt model - Epoch 12100/50000, Loss: 0.008489
# Training rebuilt model - Epoch 12200/50000, Loss: 0.011237
# Training rebuilt model - Epoch 12300/50000, Loss: 0.012259
# Training rebuilt model - Epoch 12400/50000, Loss: 0.003831
# Training rebuilt model - Epoch 12500/50000, Loss: 0.012896
# Training rebuilt model - Epoch 12600/50000, Loss: 0.023949
# Training rebuilt model - Epoch 12700/50000, Loss: 0.005944
# Training rebuilt model - Epoch 12800/50000, Loss: 0.011006
# Training rebuilt model - Epoch 12900/50000, Loss: 0.006459
# Training rebuilt model - Epoch 13000/50000, Loss: 0.133084
# Training rebuilt model - Epoch 13100/50000, Loss: 0.022320
# Training rebuilt model - Epoch 13200/50000, Loss: 0.015553
# Training rebuilt model - Epoch 13300/50000, Loss: 0.011443
# Training rebuilt model - Epoch 13400/50000, Loss: 0.007470
# Training rebuilt model - Epoch 13500/50000, Loss: 0.007038
# Training rebuilt model - Epoch 13600/50000, Loss: 0.006137
# Training rebuilt model - Epoch 13700/50000, Loss: 0.006334
# Training rebuilt model - Epoch 13800/50000, Loss: 0.009146
# Training rebuilt model - Epoch 13900/50000, Loss: 0.008383
# Training rebuilt model - Epoch 14000/50000, Loss: 0.011119
# Training rebuilt model - Epoch 14100/50000, Loss: 0.009240
# Training rebuilt model - Epoch 14200/50000, Loss: 0.025786
# Training rebuilt model - Epoch 14300/50000, Loss: 0.012420
# Training rebuilt model - Epoch 14400/50000, Loss: 0.011678
# Training rebuilt model - Epoch 14500/50000, Loss: 0.007255
# Training rebuilt model - Epoch 14600/50000, Loss: 0.045446
# Training rebuilt model - Epoch 14700/50000, Loss: 0.027918
# Training rebuilt model - Epoch 14800/50000, Loss: 0.033866
# Training rebuilt model - Epoch 14900/50000, Loss: 0.013068
# Training rebuilt model - Epoch 15000/50000, Loss: 0.017361
# Training rebuilt model - Epoch 15100/50000, Loss: 0.007640
# Training rebuilt model - Epoch 15200/50000, Loss: 0.011493
# Training rebuilt model - Epoch 15300/50000, Loss: 0.008974
# Training rebuilt model - Epoch 15400/50000, Loss: 0.003277
# Training rebuilt model - Epoch 15500/50000, Loss: 0.009977
# Training rebuilt model - Epoch 15600/50000, Loss: 0.012977
# Training rebuilt model - Epoch 15700/50000, Loss: 0.005871
# Training rebuilt model - Epoch 15800/50000, Loss: 0.021051
# Training rebuilt model - Epoch 15900/50000, Loss: 0.009730
# Training rebuilt model - Epoch 16000/50000, Loss: 0.007635
# Training rebuilt model - Epoch 16100/50000, Loss: 0.004130
# Training rebuilt model - Epoch 16200/50000, Loss: 0.043184
# Training rebuilt model - Epoch 16300/50000, Loss: 0.021984
# Training rebuilt model - Epoch 16400/50000, Loss: 0.020183
# Training rebuilt model - Epoch 16500/50000, Loss: 0.013836
# Training rebuilt model - Epoch 16600/50000, Loss: 0.013872
# Training rebuilt model - Epoch 16700/50000, Loss: 0.016761
# Training rebuilt model - Epoch 16800/50000, Loss: 0.007198
# Training rebuilt model - Epoch 16900/50000, Loss: 0.016069
# Training rebuilt model - Epoch 17000/50000, Loss: 0.008051
# Training rebuilt model - Epoch 17100/50000, Loss: 0.005857
# Training rebuilt model - Epoch 17200/50000, Loss: 0.004998
# Training rebuilt model - Epoch 17300/50000, Loss: 0.015221
# Training rebuilt model - Epoch 17400/50000, Loss: 0.005803
# Training rebuilt model - Epoch 17500/50000, Loss: 0.009614
# Training rebuilt model - Epoch 17600/50000, Loss: 0.006245
# Training rebuilt model - Epoch 17700/50000, Loss: 0.011374
# Training rebuilt model - Epoch 17800/50000, Loss: 0.005605
# Training rebuilt model - Epoch 17900/50000, Loss: 0.009919
# Training rebuilt model - Epoch 18000/50000, Loss: 0.006240
# Training rebuilt model - Epoch 18100/50000, Loss: 0.003387
# Training rebuilt model - Epoch 18200/50000, Loss: 0.006187
# Training rebuilt model - Epoch 18300/50000, Loss: 0.007084
# Training rebuilt model - Epoch 18400/50000, Loss: 0.068163
# Training rebuilt model - Epoch 18500/50000, Loss: 0.025856
# Training rebuilt model - Epoch 18600/50000, Loss: 0.024253
# Training rebuilt model - Epoch 18700/50000, Loss: 0.019616
# Training rebuilt model - Epoch 18800/50000, Loss: 0.011551
# Training rebuilt model - Epoch 18900/50000, Loss: 0.017199
# Training rebuilt model - Epoch 19000/50000, Loss: 0.012932
# Training rebuilt model - Epoch 19100/50000, Loss: 0.011478
# Training rebuilt model - Epoch 19200/50000, Loss: 0.006200
# Training rebuilt model - Epoch 19300/50000, Loss: 0.011027
# Training rebuilt model - Epoch 19400/50000, Loss: 0.009234
# Training rebuilt model - Epoch 19500/50000, Loss: 0.004279
# Training rebuilt model - Epoch 19600/50000, Loss: 0.005660
# Training rebuilt model - Epoch 19700/50000, Loss: 0.013466
# Training rebuilt model - Epoch 19800/50000, Loss: 0.003948
# Training rebuilt model - Epoch 19900/50000, Loss: 0.008292
# Training rebuilt model - Epoch 20000/50000, Loss: 0.007558
# Training rebuilt model - Epoch 20100/50000, Loss: 0.012243
# Training rebuilt model - Epoch 20200/50000, Loss: 0.003575
# Training rebuilt model - Epoch 20300/50000, Loss: 0.028852
# Training rebuilt model - Epoch 20400/50000, Loss: 0.005346
# Training rebuilt model - Epoch 20500/50000, Loss: 0.016434
# Training rebuilt model - Epoch 20600/50000, Loss: 0.011470
# Training rebuilt model - Epoch 20700/50000, Loss: 0.013051
# Training rebuilt model - Epoch 20800/50000, Loss: 0.016497
# Training rebuilt model - Epoch 20900/50000, Loss: 0.006038
# Training rebuilt model - Epoch 21000/50000, Loss: 0.007755
# Training rebuilt model - Epoch 21100/50000, Loss: 0.006743
# Training rebuilt model - Epoch 21200/50000, Loss: 0.004606
# Training rebuilt model - Epoch 21300/50000, Loss: 0.012408
# Training rebuilt model - Epoch 21400/50000, Loss: 0.009011
# Training rebuilt model - Epoch 21500/50000, Loss: 0.017799
# Training rebuilt model - Epoch 21600/50000, Loss: 0.005726
# Training rebuilt model - Epoch 21700/50000, Loss: 0.007441
# Training rebuilt model - Epoch 21800/50000, Loss: 0.093687
# Training rebuilt model - Epoch 21900/50000, Loss: 0.011116
# Training rebuilt model - Epoch 22000/50000, Loss: 0.012968
# Training rebuilt model - Epoch 22100/50000, Loss: 0.007708
# Training rebuilt model - Epoch 22200/50000, Loss: 0.010676
# Training rebuilt model - Epoch 22300/50000, Loss: 0.006513
# Training rebuilt model - Epoch 22400/50000, Loss: 0.004961
# Training rebuilt model - Epoch 22500/50000, Loss: 0.012251
# Training rebuilt model - Epoch 22600/50000, Loss: 0.005896
# Training rebuilt model - Epoch 22700/50000, Loss: 0.016497
# Training rebuilt model - Epoch 22800/50000, Loss: 0.008646
# Training rebuilt model - Epoch 22900/50000, Loss: 0.006322
# Training rebuilt model - Epoch 23000/50000, Loss: 0.473980
# Training rebuilt model - Epoch 23100/50000, Loss: 0.201027
# Training rebuilt model - Epoch 23200/50000, Loss: 0.147573
# Training rebuilt model - Epoch 23300/50000, Loss: 0.130074
# Training rebuilt model - Epoch 23400/50000, Loss: 0.075933
# Training rebuilt model - Epoch 23500/50000, Loss: 0.048400
# Training rebuilt model - Epoch 23600/50000, Loss: 0.026312
# Training rebuilt model - Epoch 23700/50000, Loss: 0.026784
# Training rebuilt model - Epoch 23800/50000, Loss: 0.020945
# Training rebuilt model - Epoch 23900/50000, Loss: 0.026346
# Training rebuilt model - Epoch 24000/50000, Loss: 0.019970
# Training rebuilt model - Epoch 24100/50000, Loss: 0.008822
# Training rebuilt model - Epoch 24200/50000, Loss: 0.008328
# Training rebuilt model - Epoch 24300/50000, Loss: 0.011587
# Training rebuilt model - Epoch 24400/50000, Loss: 0.008098
# Training rebuilt model - Epoch 24500/50000, Loss: 0.004927
# Training rebuilt model - Epoch 24600/50000, Loss: 0.006229
# Training rebuilt model - Epoch 24700/50000, Loss: 0.006946
# Training rebuilt model - Epoch 24800/50000, Loss: 0.006404
# Training rebuilt model - Epoch 24900/50000, Loss: 0.008827
# Training rebuilt model - Epoch 25000/50000, Loss: 0.015038
# Training rebuilt model - Epoch 25100/50000, Loss: 0.008609
# Training rebuilt model - Epoch 25200/50000, Loss: 0.006585
# Training rebuilt model - Epoch 25300/50000, Loss: 0.005693
# Training rebuilt model - Epoch 25400/50000, Loss: 0.010258
# Training rebuilt model - Epoch 25500/50000, Loss: 0.019098
# Training rebuilt model - Epoch 25600/50000, Loss: 0.004165
# Training rebuilt model - Epoch 25700/50000, Loss: 0.012035
# Training rebuilt model - Epoch 25800/50000, Loss: 0.021717
# Training rebuilt model - Epoch 25900/50000, Loss: 0.019176
# Training rebuilt model - Epoch 26000/50000, Loss: 0.011840
# Training rebuilt model - Epoch 26100/50000, Loss: 0.006698
# Training rebuilt model - Epoch 26200/50000, Loss: 0.007332
# Training rebuilt model - Epoch 26300/50000, Loss: 0.008172
# Training rebuilt model - Epoch 26400/50000, Loss: 0.008776
# Training rebuilt model - Epoch 26500/50000, Loss: 0.003327
# Training rebuilt model - Epoch 26600/50000, Loss: 0.003721
# Training rebuilt model - Epoch 26700/50000, Loss: 0.006119
# Training rebuilt model - Epoch 26800/50000, Loss: 0.004102
# Training rebuilt model - Epoch 26900/50000, Loss: 0.004250
# Training rebuilt model - Epoch 27000/50000, Loss: 0.017608
# Training rebuilt model - Epoch 27100/50000, Loss: 0.019898
# Training rebuilt model - Epoch 27200/50000, Loss: 0.007633
# Training rebuilt model - Epoch 27300/50000, Loss: 0.011429
# Training rebuilt model - Epoch 27400/50000, Loss: 0.005532
# Training rebuilt model - Epoch 27500/50000, Loss: 0.010267
# Training rebuilt model - Epoch 27600/50000, Loss: 0.008843
# Training rebuilt model - Epoch 27700/50000, Loss: 0.011787
# Training rebuilt model - Epoch 27800/50000, Loss: 0.021120
# Training rebuilt model - Epoch 27900/50000, Loss: 0.006656
# Training rebuilt model - Epoch 28000/50000, Loss: 0.012413
# Training rebuilt model - Epoch 28100/50000, Loss: 0.012747
# Training rebuilt model - Epoch 28200/50000, Loss: 0.004715
# Training rebuilt model - Epoch 28300/50000, Loss: 0.005191
# Training rebuilt model - Epoch 28400/50000, Loss: 0.004278
# Training rebuilt model - Epoch 28500/50000, Loss: 0.012352
# Training rebuilt model - Epoch 28600/50000, Loss: 0.023352
# Training rebuilt model - Epoch 28700/50000, Loss: 0.010893
# Training rebuilt model - Epoch 28800/50000, Loss: 0.008331
# Training rebuilt model - Epoch 28900/50000, Loss: 0.005330
# Training rebuilt model - Epoch 29000/50000, Loss: 0.019845
# Training rebuilt model - Epoch 29100/50000, Loss: 0.006074
# Training rebuilt model - Epoch 29200/50000, Loss: 0.004698
# Training rebuilt model - Epoch 29300/50000, Loss: 0.008947
# Training rebuilt model - Epoch 29400/50000, Loss: 0.007828
# Training rebuilt model - Epoch 29500/50000, Loss: 0.006623
# Training rebuilt model - Epoch 29600/50000, Loss: 0.019719
# Training rebuilt model - Epoch 29700/50000, Loss: 0.015238
# Training rebuilt model - Epoch 29800/50000, Loss: 0.004659
# Training rebuilt model - Epoch 29900/50000, Loss: 0.014797
# Training rebuilt model - Epoch 30000/50000, Loss: 0.003875
# Training rebuilt model - Epoch 30100/50000, Loss: 0.006203
# Training rebuilt model - Epoch 30200/50000, Loss: 0.007094
# Training rebuilt model - Epoch 30300/50000, Loss: 0.028767
# Training rebuilt model - Epoch 30400/50000, Loss: 0.015922
# Training rebuilt model - Epoch 30500/50000, Loss: 0.015098
# Training rebuilt model - Epoch 30600/50000, Loss: 0.012826
# Training rebuilt model - Epoch 30700/50000, Loss: 0.012025
# Training rebuilt model - Epoch 30800/50000, Loss: 0.009820
# Training rebuilt model - Epoch 30900/50000, Loss: 0.007584
# Training rebuilt model - Epoch 31000/50000, Loss: 0.004428
# Training rebuilt model - Epoch 31100/50000, Loss: 0.007845
# Training rebuilt model - Epoch 31200/50000, Loss: 0.016654
# Training rebuilt model - Epoch 31300/50000, Loss: 0.005867
# Training rebuilt model - Epoch 31400/50000, Loss: 0.006490
# Training rebuilt model - Epoch 31500/50000, Loss: 0.005275
# Training rebuilt model - Epoch 31600/50000, Loss: 0.010877
# Training rebuilt model - Epoch 31700/50000, Loss: 0.006876
# Training rebuilt model - Epoch 31800/50000, Loss: 0.005306
# Training rebuilt model - Epoch 31900/50000, Loss: 0.009519
# Training rebuilt model - Epoch 32000/50000, Loss: 0.014018
# Training rebuilt model - Epoch 32100/50000, Loss: 0.004320
# Training rebuilt model - Epoch 32200/50000, Loss: 0.018111
# Training rebuilt model - Epoch 32300/50000, Loss: 0.012600
# Training rebuilt model - Epoch 32400/50000, Loss: 0.010443
# Training rebuilt model - Epoch 32500/50000, Loss: 0.006245
# Training rebuilt model - Epoch 32600/50000, Loss: 0.005455
# Training rebuilt model - Epoch 32700/50000, Loss: 0.002725
# Training rebuilt model - Epoch 32800/50000, Loss: 0.007528
# Training rebuilt model - Epoch 32900/50000, Loss: 0.003187
# Training rebuilt model - Epoch 33000/50000, Loss: 0.010107
# Training rebuilt model - Epoch 33100/50000, Loss: 0.012584
# Training rebuilt model - Epoch 33200/50000, Loss: 0.004016
# Training rebuilt model - Epoch 33300/50000, Loss: 0.051526
# Training rebuilt model - Epoch 33400/50000, Loss: 0.010739
# Training rebuilt model - Epoch 33500/50000, Loss: 0.009874
# Training rebuilt model - Epoch 33600/50000, Loss: 0.007128
# Training rebuilt model - Epoch 33700/50000, Loss: 0.004335
# Training rebuilt model - Epoch 33800/50000, Loss: 0.009115
# Training rebuilt model - Epoch 33900/50000, Loss: 0.005528
# Training rebuilt model - Epoch 34000/50000, Loss: 0.002657
# Training rebuilt model - Epoch 34100/50000, Loss: 0.005796
# Training rebuilt model - Epoch 34200/50000, Loss: 0.004824
# Training rebuilt model - Epoch 34300/50000, Loss: 0.019096
# Training rebuilt model - Epoch 34400/50000, Loss: 0.012684
# Training rebuilt model - Epoch 34500/50000, Loss: 0.003748
# Training rebuilt model - Epoch 34600/50000, Loss: 0.008988
# Training rebuilt model - Epoch 34700/50000, Loss: 0.004454
# Training rebuilt model - Epoch 34800/50000, Loss: 0.006281
# Training rebuilt model - Epoch 34900/50000, Loss: 0.003885
# Training rebuilt model - Epoch 35000/50000, Loss: 0.007274
# Training rebuilt model - Epoch 35100/50000, Loss: 0.010382
# Training rebuilt model - Epoch 35200/50000, Loss: 0.007273
# Training rebuilt model - Epoch 35300/50000, Loss: 0.013184
# Training rebuilt model - Epoch 35400/50000, Loss: 0.006350
# Training rebuilt model - Epoch 35500/50000, Loss: 0.004954
# Training rebuilt model - Epoch 35600/50000, Loss: 0.101995
# Training rebuilt model - Epoch 35700/50000, Loss: 0.008807
# Training rebuilt model - Epoch 35800/50000, Loss: 0.005544
# Training rebuilt model - Epoch 35900/50000, Loss: 0.004292
# Training rebuilt model - Epoch 36000/50000, Loss: 0.005834
# Training rebuilt model - Epoch 36100/50000, Loss: 0.003709
# Training rebuilt model - Epoch 36200/50000, Loss: 0.008947
# Training rebuilt model - Epoch 36300/50000, Loss: 0.004278
# Training rebuilt model - Epoch 36400/50000, Loss: 0.005337
# Training rebuilt model - Epoch 36500/50000, Loss: 0.018073
# Training rebuilt model - Epoch 36600/50000, Loss: 0.008865
# Training rebuilt model - Epoch 36700/50000, Loss: 0.007662
# Training rebuilt model - Epoch 36800/50000, Loss: 0.004195
# Training rebuilt model - Epoch 36900/50000, Loss: 0.015861
# Training rebuilt model - Epoch 37000/50000, Loss: 0.003754
# Training rebuilt model - Epoch 37100/50000, Loss: 0.012474
# Training rebuilt model - Epoch 37200/50000, Loss: 0.004994
# Training rebuilt model - Epoch 37300/50000, Loss: 0.004133
# Training rebuilt model - Epoch 37400/50000, Loss: 0.004721
# Training rebuilt model - Epoch 37500/50000, Loss: 0.041303
# Training rebuilt model - Epoch 37600/50000, Loss: 0.025948
# Training rebuilt model - Epoch 37700/50000, Loss: 0.014242
# Training rebuilt model - Epoch 37800/50000, Loss: 0.014746
# Training rebuilt model - Epoch 37900/50000, Loss: 0.007052
# Training rebuilt model - Epoch 38000/50000, Loss: 0.008168
# Training rebuilt model - Epoch 38100/50000, Loss: 0.013045
# Training rebuilt model - Epoch 38200/50000, Loss: 0.013047
# Training rebuilt model - Epoch 38300/50000, Loss: 0.014281
# Training rebuilt model - Epoch 38400/50000, Loss: 0.008037
# Training rebuilt model - Epoch 38500/50000, Loss: 0.007189
# Training rebuilt model - Epoch 38600/50000, Loss: 0.004730
# Training rebuilt model - Epoch 38700/50000, Loss: 0.014414
# Training rebuilt model - Epoch 38800/50000, Loss: 0.015818
# Training rebuilt model - Epoch 38900/50000, Loss: 0.014544
# Training rebuilt model - Epoch 39000/50000, Loss: 0.007736
# Training rebuilt model - Epoch 39100/50000, Loss: 0.007238
# Training rebuilt model - Epoch 39200/50000, Loss: 0.038183
# Training rebuilt model - Epoch 39300/50000, Loss: 0.011858
# Training rebuilt model - Epoch 39400/50000, Loss: 0.005961
# Training rebuilt model - Epoch 39500/50000, Loss: 0.015886
# Training rebuilt model - Epoch 39600/50000, Loss: 0.008682
# Training rebuilt model - Epoch 39700/50000, Loss: 0.010492
# Training rebuilt model - Epoch 39800/50000, Loss: 0.007360
# Training rebuilt model - Epoch 39900/50000, Loss: 0.013449
# Training rebuilt model - Epoch 40000/50000, Loss: 0.011918
# Training rebuilt model - Epoch 40100/50000, Loss: 0.010604
# Training rebuilt model - Epoch 40200/50000, Loss: 0.005745
# Training rebuilt model - Epoch 40300/50000, Loss: 0.008762
# Training rebuilt model - Epoch 40400/50000, Loss: 0.041008
# Training rebuilt model - Epoch 40500/50000, Loss: 0.021466
# Training rebuilt model - Epoch 40600/50000, Loss: 0.035102
# Training rebuilt model - Epoch 40700/50000, Loss: 0.017882
# Training rebuilt model - Epoch 40800/50000, Loss: 0.012785
# Training rebuilt model - Epoch 40900/50000, Loss: 0.016336
# Training rebuilt model - Epoch 41000/50000, Loss: 0.015068
# Training rebuilt model - Epoch 41100/50000, Loss: 0.006992
# Training rebuilt model - Epoch 41200/50000, Loss: 0.007413
# Training rebuilt model - Epoch 41300/50000, Loss: 0.009335
# Training rebuilt model - Epoch 41400/50000, Loss: 0.008705
# Training rebuilt model - Epoch 41500/50000, Loss: 0.004865
# Training rebuilt model - Epoch 41600/50000, Loss: 0.005443
# Training rebuilt model - Epoch 41700/50000, Loss: 0.008183
# Training rebuilt model - Epoch 41800/50000, Loss: 0.005667
# Training rebuilt model - Epoch 41900/50000, Loss: 0.021912
# Training rebuilt model - Epoch 42000/50000, Loss: 0.008408
# Training rebuilt model - Epoch 42100/50000, Loss: 0.009608
# Training rebuilt model - Epoch 42200/50000, Loss: 0.007308
# Training rebuilt model - Epoch 42300/50000, Loss: 0.004907
# Training rebuilt model - Epoch 42400/50000, Loss: 0.005311
# Training rebuilt model - Epoch 42500/50000, Loss: 0.016801
# Training rebuilt model - Epoch 42600/50000, Loss: 0.009541
# Training rebuilt model - Epoch 42700/50000, Loss: 0.024768
# Training rebuilt model - Epoch 42800/50000, Loss: 0.021616
# Training rebuilt model - Epoch 42900/50000, Loss: 0.011963
# Training rebuilt model - Epoch 43000/50000, Loss: 0.013101
# Training rebuilt model - Epoch 43100/50000, Loss: 0.010696
# Training rebuilt model - Epoch 43200/50000, Loss: 0.014237
# Training rebuilt model - Epoch 43300/50000, Loss: 0.006874
# Training rebuilt model - Epoch 43400/50000, Loss: 0.005267
# Training rebuilt model - Epoch 43500/50000, Loss: 0.003875
# Training rebuilt model - Epoch 43600/50000, Loss: 0.006472
# Training rebuilt model - Epoch 43700/50000, Loss: 0.003978
# Training rebuilt model - Epoch 43800/50000, Loss: 0.016074
# Training rebuilt model - Epoch 43900/50000, Loss: 0.004959
# Training rebuilt model - Epoch 44000/50000, Loss: 0.006222
# Training rebuilt model - Epoch 44100/50000, Loss: 0.013350
# Training rebuilt model - Epoch 44200/50000, Loss: 0.012941
# Training rebuilt model - Epoch 44300/50000, Loss: 0.005196
# Training rebuilt model - Epoch 44400/50000, Loss: 0.027332
# Training rebuilt model - Epoch 44500/50000, Loss: 0.015980
# Training rebuilt model - Epoch 44600/50000, Loss: 0.007606
# Training rebuilt model - Epoch 44700/50000, Loss: 0.006811
# Training rebuilt model - Epoch 44800/50000, Loss: 0.005391
# Training rebuilt model - Epoch 44900/50000, Loss: 0.004101
# Training rebuilt model - Epoch 45000/50000, Loss: 0.013226
# Training rebuilt model - Epoch 45100/50000, Loss: 0.005306
# Training rebuilt model - Epoch 45200/50000, Loss: 0.017460
# Training rebuilt model - Epoch 45300/50000, Loss: 0.008809
# Training rebuilt model - Epoch 45400/50000, Loss: 0.081374
# Training rebuilt model - Epoch 45500/50000, Loss: 0.018520
# Training rebuilt model - Epoch 45600/50000, Loss: 0.015041
# Training rebuilt model - Epoch 45700/50000, Loss: 0.008428
# Training rebuilt model - Epoch 45800/50000, Loss: 0.005609
# Training rebuilt model - Epoch 45900/50000, Loss: 0.005210
# Training rebuilt model - Epoch 46000/50000, Loss: 0.015892
# Training rebuilt model - Epoch 46100/50000, Loss: 0.014065
# Training rebuilt model - Epoch 46200/50000, Loss: 0.005581
# Training rebuilt model - Epoch 46300/50000, Loss: 0.012543
# Training rebuilt model - Epoch 46400/50000, Loss: 0.009888
# Training rebuilt model - Epoch 46500/50000, Loss: 0.006552
# Training rebuilt model - Epoch 46600/50000, Loss: 0.013352
# Training rebuilt model - Epoch 46700/50000, Loss: 0.005927
# Training rebuilt model - Epoch 46800/50000, Loss: 0.023520
# Training rebuilt model - Epoch 46900/50000, Loss: 0.016050
# Training rebuilt model - Epoch 47000/50000, Loss: 0.008642
# Training rebuilt model - Epoch 47100/50000, Loss: 0.012428
# Training rebuilt model - Epoch 47200/50000, Loss: 0.007459
# Training rebuilt model - Epoch 47300/50000, Loss: 0.011615
# Training rebuilt model - Epoch 47400/50000, Loss: 0.004329
# Training rebuilt model - Epoch 47500/50000, Loss: 0.006943
# Training rebuilt model - Epoch 47600/50000, Loss: 0.007289
# Training rebuilt model - Epoch 47700/50000, Loss: 0.004629
# Training rebuilt model - Epoch 47800/50000, Loss: 0.003204
# Training rebuilt model - Epoch 47900/50000, Loss: 0.002565
# Training rebuilt model - Epoch 48000/50000, Loss: 0.024802
# Training rebuilt model - Epoch 48100/50000, Loss: 0.006361
# Training rebuilt model - Epoch 48200/50000, Loss: 0.009941
# Training rebuilt model - Epoch 48300/50000, Loss: 0.010986
# Training rebuilt model - Epoch 48400/50000, Loss: 0.014657
# Training rebuilt model - Epoch 48500/50000, Loss: 0.004003
# Training rebuilt model - Epoch 48600/50000, Loss: 0.007522
# Training rebuilt model - Epoch 48700/50000, Loss: 0.008063
# Training rebuilt model - Epoch 48800/50000, Loss: 0.093403
# Training rebuilt model - Epoch 48900/50000, Loss: 0.013976
# Training rebuilt model - Epoch 49000/50000, Loss: 0.008656
# Training rebuilt model - Epoch 49100/50000, Loss: 0.009784
# Training rebuilt model - Epoch 49200/50000, Loss: 0.010422
# Training rebuilt model - Epoch 49300/50000, Loss: 0.005477
# Training rebuilt model - Epoch 49400/50000, Loss: 0.007079
# Training rebuilt model - Epoch 49500/50000, Loss: 0.019672
# Training rebuilt model - Epoch 49600/50000, Loss: 0.006629
# Training rebuilt model - Epoch 49700/50000, Loss: 0.004651
# Training rebuilt model - Epoch 49800/50000, Loss: 0.013137
# Training rebuilt model - Epoch 49900/50000, Loss: 0.008525
# Training rebuilt model - Epoch 50000/50000, Loss: 0.008129
# ✅ Rebuilt model training completed.
# Evaluating loaded and trained model...
# Loaded/rebuilt model test set evaluation - MSE: 3315.918701, R²: -0.306891
#
# Model is ready for further evaluation and prediction.

# %% [markdown]
# ## 2.4 Hyperparameter Optimization (Optuna)
# Use Optuna to search for the hyperparameters of the MLP model, automatically finding the optimal network structure and training parameters.

# %%
# Flexible MLP model with customizable layers and dropout
class FlexibleMLPModel(nn.Module):
    def __init__(
        self,
        input_dim=1,
        hidden_layers=None,
        output_dim=1,
        dropout_rate=0.2,
        activation_func=nn.ReLU,
    ):
        super(FlexibleMLPModel, self).__init__()
        if hidden_layers is None:
            hidden_layers = [64, 32]

        layers = [nn.Linear(input_dim, hidden_layers[0])]
        for i in range(len(hidden_layers) - 1):
            layers.append(activation_func())
            layers.append(nn.Dropout(dropout_rate))
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i + 1]))
        layers.append(activation_func())
        layers.append(nn.Dropout(dropout_rate))
        layers.append(nn.Linear(hidden_layers[-1], output_dim))

        self.model = nn.Sequential(*layers)
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        if len(x.shape) == 1:
            x = x.unsqueeze(1)
        return self.model(x)


# Train model with early stopping
def train_model_with_early_stopping(
    model,
    X_train,
    y_train,
    X_val,
    y_val,
    optimizer,
    criterion,
    patience=30,
    max_epochs=500,
    verbose=False,
):
    best_val_loss = float("inf")
    no_improve_epochs = 0
    best_model_state = None

    for epoch in range(max_epochs):
        model.train()
        optimizer.zero_grad()
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            val_pred = model(X_val)
            val_loss = criterion(val_pred, y_val).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            no_improve_epochs = 0
            best_model_state = model.state_dict().copy()
        else:
            no_improve_epochs += 1

        if no_improve_epochs >= patience:
            if verbose:
                print(f"Early stopping at epoch {epoch + 1}")
            model.load_state_dict(best_model_state)
            break

        if verbose and epoch % 50 == 0:
            print(
                f"Epoch {epoch + 1}/{max_epochs}, Train Loss: {loss.item():.6f}, Val Loss: {val_loss:.6f}"
            )

    if best_model_state:
        model.load_state_dict(best_model_state)
    return best_val_loss


# Objective function for Optuna hyperparameter tuning
def objective(trial, X_train, y_train, X_val, y_val, device, input_dim=1, output_dim=1):
    n_layers = trial.suggest_int("n_layers", 1, 5)
    hidden_layers = [trial.suggest_int(f"n_units_l{i}", 8, 256, log=True) for i in range(n_layers)]
    dropout_rate = trial.suggest_float("dropout_rate", 0.0, 0.5)
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True)
    weight_decay = trial.suggest_float("weight_decay", 1e-8, 1e-3, log=True)

    activation_name = trial.suggest_categorical("activation", ["ReLU", "LeakyReLU", "ELU", "GELU"])
    activation_functions = {
        "ReLU": nn.ReLU,
        "LeakyReLU": lambda: nn.LeakyReLU(0.1),
        "ELU": nn.ELU,
        "GELU": nn.GELU,
    }

    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])

    model = FlexibleMLPModel(
        input_dim=input_dim,
        hidden_layers=hidden_layers,
        output_dim=output_dim,
        dropout_rate=dropout_rate,
        activation_func=activation_functions[activation_name],
    ).to(device)

    criterion = nn.MSELoss()

    if optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_name == "RMSprop":
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    else:
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=0.9)

    patience = trial.suggest_int("patience", 10, 100)
    max_epochs = 2000

    val_loss = train_model_with_early_stopping(
        model, X_train, y_train, X_val, y_val, optimizer, criterion, patience=patience, max_epochs=max_epochs
    )
    return val_loss


# Evaluate model performance using MSE and R²
def evaluate_model(model, X_test, y_test, scaler_y=None):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test)
        mse = nn.MSELoss()(y_pred, y_test).item()

        if scaler_y is not None:
            y_test_np = y_test.cpu().numpy().reshape(-1, 1)
            y_pred_np = y_pred.cpu().numpy().reshape(-1, 1)
            y_test_original = scaler_y.inverse_transform(y_test_np)
            y_pred_original = scaler_y.inverse_transform(y_pred_np)
            r2 = r2_score(y_test_original, y_pred_original)
        else:
            r2 = r2_score(y_test.cpu().numpy(), y_pred.cpu().numpy())

    return mse, r2


# Run hyperparameter optimization and return best model
def run_hyperparameter_optimization(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    scaler_y=None,
    device=None,
    n_trials=50000,
    study_name="mlp_optimization",
):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    study = optuna.create_study(direction="minimize", study_name=study_name)
    objective_wrapper = lambda trial: objective(
        trial,
        X_train,
        y_train,
        X_val,
        y_val,
        device,
        X_train.shape[1] if len(X_train.shape) > 1 else 1,
        y_train.shape[1] if len(y_train.shape) > 1 else 1,
    )

    print(f"Starting hyperparameter optimization with {n_trials} trials...")
    study.optimize(objective_wrapper, n_trials=n_trials, show_progress_bar=True)

    best_params = study.best_params
    print("Best hyperparameters:")
    for param, value in best_params.items():
        print(f"- {param}: {value}")

    input_dim = X_train.shape[1] if len(X_train.shape) > 1 else 1
    output_dim = y_train.shape[1] if len(y_train.shape) > 1 else 1
    n_layers = best_params["n_layers"]
    hidden_layers = [best_params[f"n_units_l{i}"] for i in range(n_layers)]

    activation_name = best_params["activation"]
    activation_functions = {
        "ReLU": nn.ReLU,
        "LeakyReLU": lambda: nn.LeakyReLU(0.1),
        "ELU": nn.ELU,
        "GELU": nn.GELU,
    }

    best_model = FlexibleMLPModel(
        input_dim=input_dim,
        hidden_layers=hidden_layers,
        output_dim=output_dim,
        dropout_rate=best_params["dropout_rate"],
        activation_func=activation_functions[activation_name],
    ).to(device)

    if best_params["optimizer"] == "Adam":
        optimizer = optim.Adam(
            best_model.parameters(),
            lr=best_params["learning_rate"],
            weight_decay=best_params["weight_decay"],
        )
    elif best_params["optimizer"] == "RMSprop":
        optimizer = optim.RMSprop(
            best_model.parameters(),
            lr=best_params["learning_rate"],
            weight_decay=best_params["weight_decay"],
        )
    else:
        optimizer = optim.SGD(
            best_model.parameters(),
            lr=best_params["learning_rate"],
            weight_decay=best_params["weight_decay"],
            momentum=0.9,
        )

    print("Training final model on full training data...")
    criterion = nn.MSELoss()

    # Combine train and validation set
    if isinstance(X_train, torch.Tensor):
        X_full_train = torch.cat([X_train, X_val], dim=0)
        y_full_train = torch.cat([y_train, y_val], dim=0)
    else:
        X_full_train = torch.cat([torch.tensor(X_train), torch.tensor(X_val)], dim=0)
        y_full_train = torch.cat([torch.tensor(y_train), torch.tensor(y_val)], dim=0)

    best_model.train()
    max_epochs = 2000
    for epoch in range(max_epochs):
        optimizer.zero_grad()
        y_pred = best_model(X_full_train)
        loss = criterion(y_pred, y_full_train)
        loss.backward()
        optimizer.step()
        if epoch % 100 == 0:
            print(f"Epoch {epoch + 1}/{max_epochs}, Loss: {loss.item():.6f}")

    # Evaluate on test set
    mse, r2 = evaluate_model(best_model, X_test, y_test, scaler_y)
    print(f"Evaluation of best model - MSE: {mse:.6f}, R²: {r2:.6f}")

    # Visualization
    plot_optimization_history(study)
    plot_param_importances(study)
    plot_intermediate_values(study)

    return best_model, best_params, (mse, r2), study


# Visualization functions
def plot_optimization_history(study):
    plt.figure(figsize=(10, 6))
    optuna.visualization.matplotlib.plot_optimization_history(study)
    plt.title("Optimization History", fontsize=14)
    plt.xlabel("Trial", fontsize=12)
    plt.ylabel("Objective Value (MSE)", fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()


def plot_param_importances(study):
    plt.figure(figsize=(12, 8))
    optuna.visualization.matplotlib.plot_param_importances(study)
    plt.title("Parameter Importances", fontsize=14)
    plt.xlabel("Importance", fontsize=12)
    plt.ylabel("Parameter", fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()


def plot_intermediate_values(study):
    plt.figure(figsize=(10, 6))
    optuna.visualization.matplotlib.plot_intermediate_values(study)
    plt.title("Intermediate Values", fontsize=14)
    plt.xlabel("Trial", fontsize=12)
    plt.ylabel("Objective Value (MSE)", fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()


# Prediction function for future data
def predict_with_best_model(best_model, X_future, scaler_y):
    best_model.eval()
    with torch.no_grad():
        predictions_scaled = best_model(X_future)
        predictions = scaler_y.inverse_transform(predictions_scaled.cpu().numpy())
    return predictions

# %%
future_years = np.array([[2022], [2023], [2024]])
future_years_scaled = scaler_X.transform(future_years)
future_years_tensor = torch.FloatTensor(future_years_scaled).to(device)

# Get evaluation results for the final selected model
if final_best_scores and not any(np.isnan(final_best_scores)):
    best_mse, best_r2 = final_best_scores
    print(f"\nEvaluation results of the final selected model:")
    print(f"- MSE: {best_mse:.6f}")
    print(f"- R²: {best_r2:.6f}")
else:
    print("\nWarning: Evaluation scores for the final model are unavailable or invalid.")
    best_mse, best_r2 = float('nan'), float('nan')



# Use the final selected model for 2022-2024 predictions
optimized_predictions = np.full((len(future_years), 1), np.nan)
if final_best_model:
    print("\nPredicting electricity consumption for 2022-2024 using the final selected model:")
    optimized_predictions = predict_with_best_model(
        final_best_model, future_years_tensor, scaler_y
    )
else:
    print("\nFinal selected model is unavailable, cannot make predictions.")

# Create DataFrame
comparison_df = pd.DataFrame(
    {
        "Year": future_years.flatten(),
        "Optimized Model Prediction (GWh)": optimized_predictions.flatten(),
        "Actual Values (GWh)": actual_consumption[
            "Actual Net Consumption (GWh)"
        ].values,
    }
)

print("\nPrediction comparison:")
print(comparison_df)

# Calculate prediction errors
comparison_df["Optimized Model Error (%)"] = (
    abs(
        comparison_df["Optimized Model Prediction (GWh)"]
        - comparison_df["Actual Values (GWh)"]
    )
    / comparison_df["Actual Values (GWh)"]
    * 100
)


# Mean errors
optimized_mape = comparison_df["Optimized Model Error (%)"].mean()

print(f"\nMean Absolute Percentage Error (MAPE):")
print(f"- Final selected model: {optimized_mape:.2f}%")

# Visualization: prediction comparison
plt.figure(figsize=(15, 8))
plt.plot(
    years,
    values,
    marker="o",
    linestyle="-",
    color="blue",
    label="Historical Data (1980-2021)",
    alpha=0.6,
)
plt.plot(
    comparison_df["Year"],
    comparison_df["Actual Values (GWh)"],
    marker="*",
    markersize=12,
    linestyle="-",
    color="white",
    linewidth=2,
    label="Actual Values (2022-2024)",
)

if final_best_model:
    plt.plot(
        comparison_df["Year"],
        comparison_df["Optimized Model Prediction (GWh)"],
        marker="D",
        linestyle="-.",
        color="red",
        linewidth=2,
        label="Final Selected MLP Prediction",
    )
plt.title(f"Electricity Consumption Prediction Comparison", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Electricity Consumption (GWh)", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(loc="best")
plt.xticks(np.append(years[::5], comparison_df["Year"].unique()), rotation=45)
plt.tight_layout()
plt.show()

# Visualization: prediction error comparison
plt.figure(figsize=(12, 6))
bar_width = 0.35
index = np.arange(len(comparison_df["Year"].unique()))


if final_best_model:
    plt.bar(
        index + bar_width,
        comparison_df.groupby('Year')["Optimized Model Error (%)"].mean(),
        bar_width,
        color="red",
        alpha=0.7,
        label="Final Selected MLP Model",
    )
plt.title("Prediction Error ", fontsize=16)
plt.xlabel("Prediction Year", fontsize=14)
plt.ylabel("Percentage Error (%)", fontsize=14)
plt.xticks(index + bar_width / 2, comparison_df["Year"].unique())
plt.legend(loc="best")
plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()

# Optuna visualizations
if RUN_OPTUNA_OPTIMIZATION and optuna_study:
    print("\nShowing Optuna optimization process plots...")
    plot_optimization_history(optuna_study)
    plot_param_importances(optuna_study)
    plot_intermediate_values(optuna_study)
elif not RUN_OPTUNA_OPTIMIZATION:
    print("\nOptuna optimization not run, skipping Optuna-specific plots.")
else:
    print("\nOptuna optimization was set to run, but study object is unavailable. Skipping Optuna-specific plots.")

# Summary
print("\n====== Hyperparameters and Model Selection Summary ======")
if final_best_params:
    print("\nFinal selected model hyperparameters:")
    for param, value in final_best_params.items():
        print(f"- {param}: {value}")

    if final_best_params.get("n_layers"):
        hidden_layers = [
            final_best_params.get(f"n_units_l{i}") for i in range(final_best_params.get("n_layers"))
        ]
        print(f"\nFinal selected model hidden layer structure: {hidden_layers}")

    print(f"\nFinal selected model optimizer: {final_best_params.get('optimizer', 'N/A')}")
    print(f"Final selected model learning rate: {final_best_params.get('learning_rate', 'N/A')}")
else:
    print("\nFailed to load or determine final selected model hyperparameters.")

print("\n-------- Performance Summary --------")
print(f"Final selected model MSE: {best_mse:.6f}, R²: {best_r2:.6f}")
print(f"Actual prediction MAPE - Final selected: {optimized_mape:.2f}%")
print("-----------------------------")
# Out:
# Evaluation results of the final selected model:
# - MSE: 3315.918701
# - R²: -0.306891
#
# Predicting electricity consumption for 2022-2024 using the final selected model:
#
# Prediction comparison:
#    Year  Optimized Model Prediction (GWh)  Actual Values (GWh)
# 0  2022                       4030.379395               4128.2
# 1  2023                       4045.424316               4084.6
# 2  2024                       4061.407959               4086.0
#
# Mean Absolute Percentage Error (MAPE):
# - Final selected model: 1.31%
# Optuna optimization not run, skipping Optuna-specific plots.
#
# ====== Hyperparameters and Model Selection Summary ======
#
# Final selected model hyperparameters:
# - n_layers: 4
# - n_units_l0: 162
# - n_units_l1: 187
# - n_units_l2: 115
# - n_units_l3: 55
# - dropout_rate: 0.24726403007037911
# - learning_rate: 0.00895484844273611
# - weight_decay: 5.493694747461835e-05
# - activation: LeakyReLU
# - optimizer: RMSprop
# - patience: 56
#
# Final selected model hidden layer structure: [162, 187, 115, 55]
#
# Final selected model optimizer: RMSprop
# Final selected model learning rate: 0.00895484844273611
#
# -------- Performance Summary --------
# Final selected model MSE: 3315.918701, R²: -0.306891
# Actual prediction MAPE - Final selected: 1.31%
# -----------------------------

# %%
#Temporarily save the optimal hyperparameters obtained previously using optuna have.
best_params = {
    "n_layers": 4,
    "n_units_l0": 162,
    "n_units_l1": 187,
    "n_units_l2": 115,
    "n_units_l3": 55,
    "dropout_rate": 0.24726403007037911,
    "learning_rate": 0.00895484844273611,
    "weight_decay": 5.493694747461835e-05,
    "activation": "LeakyReLU",
    "optimizer": "RMSprop",
    "patience": 56
}

with open("best_params.json", "w") as f:
    json.dump(best_params, f, indent=4)
    
print("✅ The optimal parameters have been saved to best_params.json")

# verify
with open("best_params.json", "r") as f:
    loaded_params = json.load(f)
    print("\nSaved hyperparameters:")
    for key, value in loaded_params.items():
        print(f"- {key}: {value}")
# Out:
# ✅ The optimal parameters have been saved to best_params.json
#
# Saved hyperparameters:
# - n_layers: 4
# - n_units_l0: 162
# - n_units_l1: 187
# - n_units_l2: 115
# - n_units_l3: 55
# - dropout_rate: 0.24726403007037911
# - learning_rate: 0.00895484844273611
# - weight_decay: 5.493694747461835e-05
# - activation: LeakyReLU
# - optimizer: RMSprop
# - patience: 56
